# %%
#################################
#Run this cell if using Google COLAB
#################################

#clone the repository and the data to run the notebook on Google Colab
# !git clone https://github.com/GfellerLab/DeepTCRpred
# !pip install wget >> /dev/null 
# !pip install pytorch_lightning==1.6.0 >> /dev/null 
# %cd DeepTCRpred

# %% [markdown]
# # DeepTCRpred
#
# DeepTCRpred is a sequence-based TCR-pMHC interaction predictor. TCR binding predictions are currently possible for 146 pMHCs. For 43 pMHC robust predictions were achieved in internal cross validation, while models with less than 50 training TCRs have low confidence.
#
# A list of all DeepTCRpred models and additional information is available at ./pretrained_models/info_models.csv

# %%
import pandas as pd
import wget
import os
df_info = pd.read_csv("./pretrained_models/info_models.csv")
df_info
# Out:
#       DeepTCRpred_model_name       Peptide  \
# 0    H2-IAb_DIYKGVYQFKSV  DIYKGVYQFKSV
# 1        A0201_GILGFVFTL     GILGFVFTL
# 2        H2-Kb_SSYRRPVGI     SSYRRPVGI
# 3       H2-Db_SSLENFRAYV    SSLENFRAYV
# 4        A0201_LLWNGPMAV     LLWNGPMAV
# ..                   ...           ...
# 141      DQ2_PQPELPYPQPE   PQPELPYPQPE
# 142       H2-Kb_KGYVYQGL      KGYVYQGL
# 143     B4402_QELIRQGTDY    QELIRQGTDY
# 144     A0201_RLITGRLQSL    RLITGRLQSL
# 145      A0201_YVLTWIVGA     YVLTWIVGA
#
#                                                 Origin MHC_class          MHC  \
# 0    Lymphocytic choriomeningitis mammarenavirus (L...     MHCII       H2-IAb
# 1                                   Influenza A virus       MHCI  HLA-A*02:01
# 2                                   Influenza A virus       MHCI        H2-Kb
# 3                                   Influenza A virus       MHCI        H2-Db
# 4                             Yellow fever virus (YFV)      MHCI  HLA-A*02:01
# ...

# %% [markdown]
# The input of DeepTCRpred are paired TCRs (V,J gene and CDR3 sequence) like those in the file ./test/test.out.

# %%
input_tcrs = pd.read_csv("./test/test.csv")
input_tcrs
# Out:
#                 cdr3_TRA          cdr3_TRB        TRAV    TRAJ      TRBV  \
# 0           CARGSNYNVLYF     CASRGQSQNTLYF     TRAV14D  TRAJ21  TRBV13-3
# 1        CAMSAIMNRDDKIIF  CASRPNPGQGSYEQYF      TRAV17   TRAJ9    TRBV30
# 2           CAVQRGGQKLLF   CASSPPQRLQETQYF      TRAV19  TRAJ10    TRBV19
# 3     CAASIVWGSNFGNEKLTF     CASRTGDGQPQHF  TRAV14/DV4  TRAJ26  TRBV10-3
# 4          CAAGSYNFNKFYF    CASSLSGGRTEAFF    TRAV12-3  TRAJ10     TRBV9
# ...                  ...               ...         ...     ...       ...
# 998      CAGRDYGGATNKLIF     CSVRLVSKNIQYF      TRAV17   TRAJ9  TRBV12-3
# 999      CAVRDKGTGGFKTIF   CASSLTGTGAQEQYF  TRAV14/DV4  TRAJ17   TRBV6-6
# 1000     CAGTDRGSTLGRLYF  CASSQVKVSSYNEQFF  TRAV14/DV4   TRAJ3   TRBV7-9
# 1001      CAATYGTNAGKSTF    CASSQNGVGGEQYF     TRAV8-2  TRAJ39   TRBV5-5
# 1002     CVVSDRGSTLGRLYF  CASSDPRPGGNSPLHF      TRAV17  TRAJ58   TRBV5-1
#
#          TRBJ
# 0     TRBJ2-4
# 1     TRBJ2-7
# 2     TRBJ1-2
# 3     TRBJ2-1
# ...

# %% [markdown]
# To run DeepTCRpred, 3 arguments are required:
# 1. --model (the DeepTCRpred model for the target pMHC).
# 2. --input (the list of TCRs)
# 3. --out (output file) the file where the results will be stored.
#
# E.g., we have a list of TCRs (./test/test.csv) and we want to determine which ones are more likely to target the HLA-A\*02:01 GILGFVFTL epitope (DeepTCRpred model = A0201_GILGFVFTL). We save the results in ./test/out_A0201_GILGFVFTL.csv.
# The code to run is:

# %%
# !python DeepTCRpred.py --model A0201_GILGFVFTL --input ./test/test.csv --out ./test/out_A0201_GILGFVFTL.csv
#Please note the leading "!" which allows you to run bash code in the notebook
# Out:
# #########################################################################
# ###### DeepTCRpred: a sequence-based predictor of TCR-pMHC interaction  ####
# #########################################################################
# DeepTCRpred model A0201_GILGFVFTL
# Computing binding predictions for ./test/test.csv
# Testing DataLoader 0: 100%|████████████████| 1003/1003 [00:05<00:00, 169.60it/s]
# The results are stored in ./test/out_A0201_GILGFVFTL.csv.

# %% [markdown]
# Done! The results are sorted from the most probable binder to the least, and we can now proceed with their analysis. We provide both the raw DeepTCRpred score and the %rank. In the paper, we observed that most true binders have a % rank < 0.1

# %%
results_GIL = pd.read_csv("./test/out_A0201_GILGFVFTL.csv", comment = '#')
results_GIL
# Out:
#                 cdr3_TRA         cdr3_TRB        TRAV    TRAJ      TRBV  \
# 0           CAGGGSQGNLIF    CASSIRSSYEQYF      TRAV27  TRAJ42    TRBV19
# 1         CAGQYGGSQGNLIF    CASSIRSTDTQYF      TRAV12  TRAJ42    TRBV19
# 2        CAFINGSSNTGKLIF  CATSSFLAVSYEQYF     TRAV1-2  TRAJ29   TRBV3-1
# 3         CAASIDGRNNDMRF  CASSPFTGPPYEQYF  TRAV14/DV4  TRAJ45    TRBV19
# 4     CAYRSPWGMGGSQGNLIF    CATSFMVQETQYF    TRAV13-1   TRAJ6    TRBV19
# ...                  ...              ...         ...     ...       ...
# 998     CAEISFFSGGYNKLIF    CSALAGGLNTQYF      TRAV21  TRAJ49     TRBV9
# 999       CAVTDGAGSYQLTF   CASSPSGITGELFF       TRAV2  TRAJ42   TRBV5-8
# 1000       CAVRWDTGNQFYF  CASSQTGRYQETQYF     TRAV8-4  TRAJ26     TRBV9
# 1001       CAVSPTGRRALTF   CATSPGQNTGELFF       TRAV2  TRAJ52  TRBV10-3
# 1002     CALTKPGAGSYQLTF   CASRPTRRVEKLFF     TRAV9-2   TRAJ9    TRBV15
#
#          TRBJ    score  perc_rank
# 0     TRBJ2-6  3.85309    0.00040
# ...

# %% [markdown]
# Not all the 146 pretrained models are stored on GitHub. To make predictions for another pMHC we first need to download the corresponding DeepTCRpred model.
# For example, if we want to study the HLA-A\*02:01,YLQPRTFLL epitope from the SARS-CoV-2 with DeepTCRpred model_name A0201_YLQPRTFLL, we can download it by running:

# %%
# !python DeepTCRpred.py --download A0201_YLQPRTFLL
# Out:
# DeepTCRpred model already downloaded

# %% [markdown]
#  Now we can make predictions for the new pMHC.

# %%
# !python DeepTCRpred.py --model A0201_YLQPRTFLL --input ./test/test.csv --out ./test/out_A0201_YLQPRTFLL.csv
# Out:
# #########################################################################
# ###### DeepTCRpred: a sequence-based predictor of TCR-pMHC interaction  ####
# #########################################################################
# DeepTCRpred model A0201_YLQPRTFLL
# Computing binding predictions for ./test/test.csv
# Testing DataLoader 0: 100%|████████████████| 1003/1003 [00:05<00:00, 197.52it/s]
# The results are stored in ./test/out_A0201_YLQPRTFLL.csv.

# %%
results_LLW = pd.read_csv("./test/out_A0201_YLQPRTFLL.csv", comment = '#')
results_LLW
# Out:
#               cdr3_TRA            cdr3_TRB      TRAV    TRAJ      TRBV  \
# 0          CAANRDDKIIF      CSVEFKSRAGELFF  TRAV12-1  TRAJ53  TRBV11-3
# 1         CAENLGENQFYF       CATIDTNTGELFF  TRAV13-2  TRAJ47   TRBV4-1
# 2      CVVSLRDNYGQNFVF       CASSDTDTGELFF    TRAV19  TRAJ42   TRBV7-8
# 3          CAARGFQKLVF        CSVDRTNEKLFF    TRAV21  TRAJ29    TRBV27
# 4          CAVYEDDKIIF      CASSLGTDGNEQFF   TRAV1-2  TRAJ23   TRBV6-5
# ...                ...                 ...       ...     ...       ...
# 998   CIVRVGGSSNTGKLIF    CASSQGWGAEGNTIYF    TRAV19  TRAJ45    TRBV19
# 999   CAASTPSGGGADGLTF     CASSQGDQHTDTQYF     TRAV6  TRAJ26  TRBV24-1
# 1000  CAVRIYNAGNNRKLIW       CASSPIDGYGYTF    TRAV17  TRAJ16    TRBV28
# 1001   CAVGGYGGSQGNLIF   CASSLWRGLSAGNTIYF  TRAV26-2  TRAJ47    TRBV27
# 1002   CILSLRYRVNRKLTF  CASSYFRRRERSVAAQYF  TRAV26-1  TRAJ45   TRBV5-5
#
#          TRBJ    score  perc_rank
# 0     TRBJ2-7  2.84108    0.39592
# 1     TRBJ1-5  2.46276    0.88953
# ...

# %% [markdown]
# If you want to test your own set of TCRs you can upload it to Google Colab by clicking on the "Upload to session storage" button in the top left corner, which will upload your file in the '/content/' folder.
#
#  Next, run DeepTCRpred specifying the path to your TCRs file (e.g. --input /content/your_file.csv). Please refer to the ./test/test.csv file for the correct input format.
#
#  Please note that Google Colab sessions have a time limit of 12 hours, after which they will automatically shut down. Download your results to avoid losing your work.

# %% [markdown]
# ![](./upload_TCR_file.png)
